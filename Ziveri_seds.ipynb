# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import scipy as sc
from scipy import stats
# %matplotlib inline
import seaborn as sns
#Make it so you can see all the columns when you print a table
pd.options.display.max_columns = 400
pd.options.display.max_rows = 40
from scipy import stats
import cmocean
#import gsw
from matplotlib import rcParams
from matplotlib import gridspec
#from brokenaxes import brokenaxes
from matplotlib import cm
from matplotlib.colors import ListedColormap
from matplotlib.colors import LinearSegmentedColormap
from matplotlib import colors
from matplotlib import cm
from matplotlib.colors import ListedColormap
from matplotlib.colors import LinearSegmentedColormap
import matplotlib
from mpl_toolkits.axes_grid1 import make_axes_locatable
import xarray as xr
import cartopy as cart
from cartopy import config
import cartopy.crs as ccrs
import matplotlib.path as mpath
plt.style.use('classic')
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']

# %%
path = '/Users/FrankieMacbook/Documents/UW/Projects/Ziveri_Sediments/'
data = pd.read_excel(path+'Wet Sieve Datasheet.xlsx')

# %%
path = 'Sieved_seds_data_compiled (1).xlsx'

# %%
data = data.dropna(subset=['<10 um Wt'])
data
# Out:
#     Sample ID        Lon        Lat  Water Depth (m)  Total Sed Wt  \
# 0      LP ST1  -9.494350  42.022933             1333        0.3013
# 1      LP ST3 -24.592067  37.156550             1616        0.3009
# 2      LP ST4 -28.839350  40.934483             1664        0.3002
# 3      LP ST6 -27.952333  49.144033             2296        0.2999
# 4      LP ST8 -20.824000  57.033283             1877        0.2998
# 5      LP ST9 -19.921533  59.753533             2730        0.3005
# 6     LP ST10  -6.939433  62.923333              688        0.2995
# 7     LP ST11   0.793233  64.954033             2740        0.3006
# 8     LP ST12   7.649933  67.006300             1060        0.3001
# 9     LP ST16  12.198450  76.856700             1132        0.2992
# 10  LP ST16.2  13.061600  77.233000              209        0.3000
# 11    LP ST18 -18.556467  63.053917              918        0.3003
#
#     >250 um Wt  250-63 um Wt  63-10 um Wt  <10 um Wt  >250 um %  250-63 um %  \
# ...

# %%
fig = plt.figure(figsize = (15,7), facecolor='white')
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']
plt.rc('font', weight=500, size=16)
ax1 = fig.add_subplot(111)
data.plot(x="Sample ID", 
          y=[">250 um % for dry tot", "250-63 um % for dry tot", "63-10 um % for dry tot", '<10 um % for dry tot'], 
          kind="bar", rot=0, stacked=True, ax=ax1)
ax1.legend(bbox_to_anchor=(1.48,1))
ax1.set_ylabel("Percentage of Grain Size Present", fontsize=20)
ax1.set_xlabel("Station Number", fontsize=20)
plt.savefig(path+'Bulk_Size_Fractions.pdf', bbox_inches='tight')
